# %%
import matplotlib.pyplot as plt
cF = [5,	4.5,	4.0,	3.5,	3.0]

fig, ax1 = plt.subplots()

plt.plot(cF, [57.2,	59.7,	66.8,	72.3,	73.2], 'ro-') # acapella onset recal
plt.plot(cF, [52.8,	58.2,	65.9,	66.2,	68.4,], 'bo-') # poly onset recall
plt.plot(cF, [71.1,	73.3,	74.5,	75.7,	72.0], 'rx-') # a cappella  aa
plt.plot(cF, [61.2,	63.3,	64.8,	64.6,	60.3], 'bx-') # poly  aa

plt.axis([2.5, 5.5, 50, 80])
plt.xlabel('cF')
ax1.ylabel('onset recall and alignment accuraccy')
